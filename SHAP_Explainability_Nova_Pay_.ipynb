# %% [markdown]
# <a href="https://colab.research.google.com/github/NdumbiData/Fraudulent-Transaction-Detection-for-Digital-Money-Transfer/blob/main/SHAP_Explainability_Nova_Pay_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries for SHAP analysis

# Data analysis
import pandas as pd
import numpy as np

import shap

# %%
print(shap.__version__)
# Out:
# 0.50.0

# %%
# import dataset

df = pd.read_csv('/content/drive/MyDrive/Data Science Internship/Modelled_data_nova_pay_Combined.csv')


df.head(1)
# Out:
#                          transaction_id                           customer_id  \
# 0  fee8542d-8ee6-4b0d-9671-c294dd08ed26  402cccc9-28de-45b3-9af7-cc5302aa1f93
#
#                           timestamp home_country source_currency  \
# 0  2022-10-03 18:40:59.468549+00:00           us             USD
#
#   dest_currency channel  amount_src  amount_usd   fee  ...  day_of_week  \
# 0           CAD     atm      278.19      278.19  4.25  ...            0
#
#   is_weekend  ip_risk_score_count night_hours account_very_new  account_new  \
# 0          0             low <0.3           1                0            0
#
#    velocity_burst amount_high  ip_high_risk  device_low_trust
# 0               0           0             0                 0
#
# [1 rows x 37 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import joblib

# Define the folder path (update this if you saved them in a subfolder)
path = '/content/drive/MyDrive/Data Science Internship/Models /Nova Pay Project Models logistic_regression.joblib'

# Load Logistic Regression
best_model_lr = joblib.load(path)

# Load Random Forest
rf_tuned = joblib.load(path)

# %%
# Lets create SHAP explainer for random forest

explainer_rf = shap.TreeExplainer(rf_model)

#Calculate SHAP values for the test set ( sample 100 for speed)

shap_values_rf = explainer_rf.shap_values(x_test_processed[:100])

print(f'Shap Values Shape: {shap_values_rf.shape}')
print("Explainer ready for Random Forest")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-4032727497.py in <cell line: 0>()
#       1 # Lets create SHAP explainer for random forest
#       2
# ----> 3 explainer_rf = shap.TreeExplainer(rf_model)
#       4
#       5 #Calculate SHAP values for the test set ( sample 100 for speed)
#
# NameError: name 'rf_model' is not defined
